# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# policy plot
# 0 = stay (dot)
# 1 = left (left arrow)
# 2 = right (right arrow)

reward = np.loadtxt("../build/ci_cost.out")
policy = np.loadtxt("../build/ci_policy.out")

# plot for each state (x axis)
for i in range(policy.shape[0]):
    if policy[i] == 0:
        plt.plot(i, reward[i], 'o', color='tab:green')
    elif policy[i] == 1:
        plt.plot(i, reward[i], '<', color='tab:orange')
    elif policy[i] == 2:
        plt.plot(i, reward[i], '>', color='tab:blue')

# %%
reward = np.loadtxt("../build/ci_cost_opi.out")
policy = np.loadtxt("../build/ci_policy_opi.out")

# plot for each state (x axis)
for i in range(policy.shape[0]):
    if policy[i] == 0:
        plt.plot(i, reward[i], 'o', color='tab:green')
    elif policy[i] == 1:
        plt.plot(i, reward[i], '<', color='tab:orange')
    elif policy[i] == 2:
        plt.plot(i, reward[i], '>', color='tab:blue')
